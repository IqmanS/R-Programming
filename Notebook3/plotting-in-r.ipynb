# %% [markdown]
# <a href="https://www.kaggle.com/code/iqmansingh/plotting-in-r?scriptVersionId=141313728" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # **Plotting in R**
# ---

# %%
# Generate random nubers
x <- round(runif(100, min = 1, max = 5),2)

# %% [markdown]
# ---
# ## **4.1 Scatter Plot**
# ---
# Scatter Plot with X,Y Labels and Title
#  - plot(x, y, main, xlab, ylab, xlim, ylim, axes)

# %%
plot(x, main = "Plot of x", xlab = "X Axis", ylab="Y Axis",col="steelblue")

# %% [markdown]
# ---
# ## **4.2 Histograms**
# ---
#  - hist(v,main,xlab,xlim,ylim,breaks,col,border)

# %%
hist(x,xlab = "Values",col = "aliceblue",border = "dodgerblue",breaks=20)

# %% [markdown]
# ---
# ## **4.3 Boxplot**
# ---
#  - boxplot(x, data, notch, varwidth, names, main)

# %%
boxplot(x=x, main = "Box Plot",col="coral1")

# %% [markdown]
# ---
# ## **4.4 Bivariate Plot**
# ---

# %%
# Bivariate 'scatter plot' of y vs x
y <- x^2 + runif(100)
plot(x, y, main = "Bivariate 'scatter plot' of y vs x")

# %% [markdown]
# ---
# ## **4.5 Saving the Plot**
# ---

# %%
# Saving the Plot to a file
getwd()   # Get the Current Working Directory, Similar to pwd in linux
png(filename="Plot.png")
plot(x, y, main = "Bivariate 'scatter plot' of y vs x",xlab = "X Axis", ylab="Y Axis")
dev.off()
# Go to the path and check for file
# Out:
# [1] "/kaggle/working"
# png
#   2

# %% [markdown]
# ---
# ## **4.6 Other Plots**
# ---

# %%
z1 <- list(x = x, y = y)
class(z1)
# Out:
# [1] "list"

# %%
# Plot
plot(z1)

# %%
# Variation in Plot
plot(z1, type = "l")  # l is for lines

# %% [markdown]
# ---
# ## **4.5 Increasing Order Plotting**
# ---

# %%
# Generate ording
print(x)
ord <- order(x)
# Out:
#   [1] 3.82 4.13 4.90 2.77 3.41 1.15 1.11 4.34 1.33 1.91 1.31 4.07 1.82 1.00 2.01
#  [16] 2.83 4.85 2.02 3.55 2.24 1.63 3.57 4.83 1.55 2.69 3.70 3.25 1.56 2.53 3.72
#  [31] 4.01 2.36 1.10 1.26 4.62 4.88 4.63 2.25 2.10 3.66 1.46 4.40 1.91 1.68 3.56
#  [46] 1.78 2.11 4.82 4.53 4.36 3.77 1.76 4.89 2.38 4.78 4.29 4.70 2.39 1.65 1.04
#  [61] 2.68 3.54 4.75 3.37 4.93 4.85 4.77 4.36 2.45 1.61 2.47 4.93 3.14 2.91 3.62
#  [76] 2.78 3.01 4.75 2.21 1.37 4.18 3.96 2.66 3.31 1.73 3.60 1.75 4.31 1.59 4.05
#  [91] 1.02 1.49 4.78 1.80 2.09 4.12 1.80 2.02 2.91 1.83

# %%
# Merge x, y
z <- list(x = x[ord], y = y[ord])

# %%
# lines
plot(z, type = "l", main= "X vs Y", xlab = "X Axis", ylab="Y Axis")

# %%
# Points and lines overlayed
plot(z, type = "o")

# %%
# steps
plot(z, type = "s")

# %%
# histogram-like
plot(z, type = "h")

# %% [markdown]
# ---
# ## **4.6 Grid and a curve plotting**
# ---

# %%
plot(z, type = "n")

# Uncomment each line and run
grid(lty = 1, lwd = 2)
curve(x^2, col = "blue", add = TRUE)
curve(x^2 + 1, col = "blue", add = TRUE)
points(z, pch = 20)

# %% [markdown]
# ---
# ## **4.7 Grphical Parameters**
# ---

# %%
plot(z, type = "o", col = 'red', pch = 16, cex = 2)

# %%
plot(z, col = c('red', 'blue'), pch = "+", cex = 2)

# %% [markdown]
# ---
# ## **4.8 Colors Plotting**
# ---

# %%
# List of colors
sample(colors(),10)
# Out:
#  [1] "gray95"     "chocolate1" "palegreen1" "grey28"     "green3"
#  [6] "gray100"    "tomato1"    "yellow3"    "grey51"     "darkcyan"

# %%
# default colours (palette)
palette()
# Out:
# [1] "black"   "#DF536B" "#61D04F" "#2297E6" "#28E2E5" "#CD0BBC" "#F5C710"
# [8] "gray62"

# %%
# Change palette colors
palette(sample(colors(), 10)) 
plot(runif(50), col = rep(1:10, each = 5), pch = 16, cex = 2)

# Re-run the code again

# %% [markdown]
# ---
# ## **4.9 Histogram Plotting - Frequency Plotting**
# ---

# %%
# create a grouping variable of length 100
a <- factor(sample(1:5, 100, replace = TRUE), levels = 1:5)

levels(a) <- LETTERS[1:5]

# %%
# Histogram
plot(a,col="mediumturquoise")

# %%
# Box Plot
plot(y ~ a,col="sienna2")

# %% [markdown]
# ---
# ## **4.10 Function Plotting**
# ---

# %%
plot(sin, from = -2 * pi, to = 2 * pi,col="coral")
grid()

# %%
plot(cos, from = -2 * pi, to = 2 * pi,col="coral")

# %%
 # Sign function
 damped_sin <- function(x) sin(5 * x) * exp(-x^2)

# %%
class(damped_sin)
# Out:
# [1] "function"

# %%
plot(damped_sin, from = -pi, to = pi,col="coral")
